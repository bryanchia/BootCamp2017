# %%
import pandas as pd
from datetime import datetime
import numpy as np

#Problem 1

df = pd.read_csv('DJIA.csv', delimiter =",", header = 0, index_col = 0)

df.index = pd.to_datetime(df.index)

df[df['VALUE']=="."] = np.nan

df['VALUE'] = df['VALUE'].astype(float)

# %%
#Problem 2

fri1 = pd.date_range(start='3/13/2008', periods = int(93/2) + 1, freq="WOM-1FRI")
fri2 = pd.date_range(start='3/13/2008', periods = int(93/2) , freq="WOM-3FRI" )

dates = fri1.union(fri2)

df2 = pd.read_csv('paychecks.csv', delimiter =",",names = ['paycheck'],  header = None, index_col = False)

df3 = df2.set_index(dates)

df3
# Out:
#             paycheck
# 2008-03-21   1122.26
# 2008-04-04    921.03
# 2008-04-18    962.46
# 2008-05-02   1035.97
# 2008-05-16   1078.59
# 2008-06-06   1110.97
# 2008-06-20   1121.91
# 2008-07-04    992.83
# 2008-07-18   1103.23
# 2008-08-01    944.66
# 2008-08-15   1030.07
# 2008-09-05    942.35
# 2008-09-19    909.83
# 2008-10-03   1125.79
# 2008-10-17    947.21
# 2008-11-07   1067.83
# 2008-11-21    991.64
# 2008-12-05    963.20
# 2008-12-19    912.61
# 2009-01-02   1018.91
# 2009-01-16    997.93
# 2009-02-06   1129.61
# 2009-02-20    963.64
# 2009-03-06   1009.76
# 2009-03-20    984.89
# 2009-04-03   1033.27
# 2009-04-17    934.76
# 2009-05-01   1122.10
# 2009-05-15   1032.46
# 2009-06-05    999.56
# ...              ...
# 2010-11-05    982.53
# 2010-11-19    910.10
# 2010-12-03    920.01
# 2010-12-17    912.25
# 2011-01-07   1109.19
# 2011-01-21   1011.60
# 2011-02-04   1126.08
# 2011-02-18   1073.42
# 2011-03-04   1068.50
# 2011-03-18   1031.05
# 2011-04-01   1102.34
# ...

# %%
#Problem 4


df4 = pd.read_csv('finances.csv', delimiter =",",  header = 0, index_col = False)

p = pd.period_range("1978-09", periods = len(df4), freq="Q-AUG")

df41 = df4.set_index(p)

df41
# Out:
#          EARNINGS   EXPENSES
# 1979Q1  372572.16  122611.27
# 1979Q2  419440.58  133176.18
# 1979Q3  419766.49  154670.69
# 1979Q4  361453.31  209360.42
# 1980Q1  354463.33  174147.13
# 1980Q2  340758.31  171127.13
# 1980Q3  461209.09  201862.17
# 1980Q4  416877.39  148556.39
# 1981Q1  413084.91  134615.85
# 1981Q2  396260.93  179207.48
# 1981Q3  349398.07  133338.44
# 1981Q4  322589.43  160831.10
# 1982Q1  403463.78  159107.66
# 1982Q2  421034.58  137484.84
# 1982Q3  508631.77  107515.01
# 1982Q4  356932.89  139948.60
# 1983Q1  415560.30  171425.29
# 1983Q2  390128.95  216644.40
# 1983Q3  363098.65  128840.24
# 1983Q4  418156.01  169636.58
# 1984Q1  425019.51  157168.73
# 1984Q2  395493.01  147952.65
# 1984Q3  401361.00  150173.88
# 1984Q4  392318.06  106092.24
# 1985Q1  414275.86  141967.36
# 1985Q2  399753.55   59649.41
# 1985Q3  409538.79  132704.43
# 1985Q4  423850.27  139784.11
# 1986Q1  371149.64  155473.41
# 1986Q2  433987.89  202024.74
# ...           ...        ...
# ...

# %%
#Problem 5: 

df5 = pd.read_csv('website_traffic.csv', delimiter =",",  header = 0, index_col = False)

df5["ENTER"] = pd.to_datetime(df5["ENTER"])
df5["LEAVE"] = pd.to_datetime(df5["LEAVE"])
df5["DURATION"] = df5["LEAVE"] - df5["ENTER"]

p = pd.to_datetime(df5["ENTER"])

df51 = df5.set_index(p)

df51['DURATION'] = df51['DURATION'].apply(lambda x: pd.to_timedelta(x))
df51['DURATION'] = df51['DURATION'].apply(lambda x: x / pd.offsets.Minute(1))

df52 = df51.resample('D').mean()

print("Daily Mean Visit Duration (In Minutes)")
print(df52)
print("\n")

df51['COUNT'] = 1
df53 = df51.resample('H').sum()

print("Daily Number of Visits (By Hour)")
print(df53)
# Out:
# Daily Mean Visit Duration (In Minutes)
#             DURATION
# ENTER
# 2016-10-07  5.078861
#
#
# Daily Number of Visits (By Hour)
#                         DURATION  COUNT
# ENTER
# 2016-10-07 01:00:00  3103.666667    618
# 2016-10-07 02:00:00  3230.666667    655
# 2016-10-07 03:00:00  3505.766667    670
# 2016-10-07 04:00:00  3185.033333    632
# 2016-10-07 05:00:00  3422.233333    672
# 2016-10-07 06:00:00  3112.083333    602
# 2016-10-07 07:00:00  3372.000000    660
# 2016-10-07 08:00:00  3342.200000    650
# 2016-10-07 09:00:00  3410.833333    665
# 2016-10-07 10:00:00  3370.416667    647
# 2016-10-07 11:00:00  3064.316667    605
# 2016-10-07 12:00:00  3312.516667    646
# 2016-10-07 13:00:00  3463.283333    670
# 2016-10-07 14:00:00  3183.133333    628
# 2016-10-07 15:00:00  2930.333333    607
# 2016-10-07 16:00:00  3329.300000    683
# 2016-10-07 17:00:00  3170.616667    632
# 2016-10-07 18:00:00  3259.083333    629
# 2016-10-07 19:00:00  3579.783333    702
# ...

# %%
#Problem 6

df_1 = df.shift(1)
df_change = df_1 - df

print("Day with largest gain:")
print(df_change.loc[df_change['VALUE'].idxmax()])
print("\n")
print("Day with largest loss")
print(df_change.loc[df_change['VALUE'].idxmin()])
print("\n")

df_month = df.resample('M').mean()
df_month.index = df_month.index.to_period("M")
df_month_change = df_month.shift(1) - df_month

print("Month with largest gain")
print("\n")
print(df_month_change.loc[df_change['VALUE'].idxmax()])
print("Month with largest loss")
print("\n")
print(df_month_change.loc[df_change['VALUE'].idxmax()])
# Out:
# Day with largest gain:
# VALUE    777.68
# Name: 2008-09-29 00:00:00, dtype: float64
#
#
# Day with largest loss
# VALUE   -936.42
# Name: 2008-10-13 00:00:00, dtype: float64
#
#
# Month with largest gain
#
#
# VALUE    416.66381
# Name: 2008-09, dtype: float64
# Month with largest loss
#
#
# VALUE    416.66381
# Name: 2008-09, dtype: float64

# %%
#Problem 7

import matplotlib.pyplot as plt
import pylab

pylab.rcParams['figure.figsize'] = (15, 10)
plt.style.use('ggplot')

df7 = df
df7['ROLL_30'] = df7['VALUE'].rolling(window=30).mean() #pd.rolling_mean(df7['VALUE'],30)
df7['ROLL_365'] = df7['VALUE'].rolling(window=365).mean()
df7['EXP_30'] = df7['VALUE'].ewm(span=30).mean()
df7['EXP_365'] = df7['VALUE'].ewm(span=365).mean()

df7.plot()
plt.legend(["Original", "Rolling(30)", "Rolling(365)", "EWMP(30)", "EWMP(365)"], fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.xlabel("Date", fontsize = 20)
plt.ylabel("Value", fontsize = 20)
plt.title("Rolling Average and EWMA", fontsize = 25)
plt.show()
