# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import pylab

pylab.rcParams['figure.figsize'] = (10, 5)

#Part A

fig1 = plt.figure()

df = pd.read_csv('lipids.csv', delimiter =",", header = 4)
df = df[df.diseased == 1]

data = df.as_matrix()

disease = np.array(data[:,0])
chol = np.array(data[:,1])
trig = np.array(data[:,2])

plt.hist(chol, edgecolor = 'k', bins=25)
plt.title ("Histogram of cholestrol", )
plt.show()
fig1.savefig('2dhist_chol.png')

# %% [markdown]
# The midpoint with the highest frequency is 237.5

# %%
#Part B
from mpl_toolkits.mplot3d import Axes3D

pylab.rcParams['figure.figsize'] = (15, 15)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

bin_num = int(25)
hist, xedges, yedges = np.histogram2d(chol, trig, bins=bin_num, range=[[100,500 ], [0, 1000]])
hist = hist / hist.sum()
x_midp = xedges[:-1] + 0.5 * (xedges[1] - xedges[0])
y_midp = yedges[:-1] + 0.5 * (yedges[1] - yedges[0])
elements = (len(xedges) - 1) * (len(yedges) - 1)
ypos, xpos = np.meshgrid(y_midp, x_midp)
xpos = xpos.flatten()
ypos = ypos.flatten()
zpos = np.zeros(elements)
dx = (xedges[1] - xedges[0]) * np.ones_like(bin_num)
dy = (yedges[1] - yedges[0]) * np.ones_like(bin_num)
dz = hist.flatten()
ax.bar3d(xpos, ypos, zpos, dx, dy, dz, color='g', zsort='average')
ax.set_xlabel('Cholestral Level', fontsize = 15)
ax.set_ylabel('Trig Level', fontsize = 15)
ax.set_zlabel('Percent of obs.', fontsize = 15)
plt.title('Histogram of those with heart disease', fontsize = 20)

plt.show()
fig.savefig('3dhist.png')

# %% [markdown]
# Those with the highest risk of heart disease are those with cholestral levels of around 237.5 and with trigliceride levels around 100 to 200.
